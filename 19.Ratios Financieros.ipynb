# %%
import pandas as pd

# %%
Naturgy = pd.read_excel("Naturgy.xlsx", sheet_name = 'BALANCE', index_col=[0])

# %%
Naturgy.fillna(0)
# Out:
#                                                       2020        2019  \
# Activos                                                0.0         0.0
# Activo corriente                                       0.0         0.0
# Efectivo                                               0.0         0.0
# Efectivo y otros activos líquidos equivalentes   3927000.0   2685000.0
# Otras inversiones a corto plazo                   558000.0    328000.0
# Efectivo total                                   4485000.0   3013000.0
# Cuentas pendientes netas                         2688000.0   3911000.0
# Inventario                                        519000.0    796000.0
# Otros activos corrientes                         5262000.0   1067000.0
# Activo corriente totale                         12954000.0   8787000.0
# Activo corriente                                       0.0         0.0
# Activos fijos                                          0.0         0.0
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
FM = Naturgy.loc['Activo corriente totale']/Naturgy.loc['Pasivo corriente total']
FM = pd.DataFrame(Fondo_Maniobra)
FM.columns=['Fondo Maniobra']

# %%
FM.T
# Out:
#                    2020     2019     2018     2017
# Fondo Maniobra  1.40043  1.32076  1.18881  1.45676

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
RT = (Naturgy.loc['Activo corriente totale']-Naturgy.loc['Inventario'])/Naturgy.loc['Pasivo corriente total']
RT = pd.DataFrame(RT)
RT.columns=['Ratio Tesorería']

# %%
RT.T
# Out:
#                      2020      2019      2018      2017
# Ratio Tesorería  1.344324  1.201112  1.067504  1.362119

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
RA = Naturgy.loc['Deuda corriente']+Naturgy.loc['Cuentas a pagar']+Naturgy.loc['Deuda a largo plazo']+Naturgy.loc['Pasivo por impuestos diferidos']
RAF = Naturgy.loc['Patrimonio de los accionistas total']/RA
RAF = pd.DataFrame
